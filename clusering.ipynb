# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np
import random as rd
# !simlord --no-sam -rr tt.fa -n 7700 -mr 1500 tt
# !./vectorize ./tt.fastq 4 8 100 > ./tt.txt
vi = np.loadtxt("tt.txt")

print(vi.shape)
X = vi
m=X.shape[0] 
n=X.shape[1] 
K=25 
n_iter=100
Centroids=np.array([]).reshape(n,0) 
for i in range(K): 
    rand=rd.randint(0,m-1) 
    Centroids=np.c_[Centroids,X[rand]] 
Centroids
# Out:
# Time for reading/generating the reference: 0:00:00.110435 h
# Time for simulation of 7700 reads: 0:00:44.998989 h.
# (7700, 136)
# array([[0.00206612, 0.00518824, 0.00561538, ..., 0.0093565 , 0.0146964 ,
#         0.00085616],
#        [0.00918274, 0.0105095 , 0.0106154 , ..., 0.00840176, 0.00613695,
#         0.0162671 ],
#        [0.00550964, 0.00452308, 0.00769231, ..., 0.00305518, 0.00419897,
#         0.00399543],
#        ...,
#        [0.00573921, 0.00784888, 0.00715385, ..., 0.0097384 , 0.0108204 ,
#         0.00299658],
#        [0.00413223, 0.00558734, 0.00738462, ..., 0.00248234, 0.00839793,
#         0.00385274],
#        [0.00642792, 0.0115738 , 0.00784615, ..., 0.00381898, 0.00532946,
#         0.0148402 ]])

# %%
Output={}

EuclidianDistance=np.array([]).reshape(m,0)

Centroids[:,0]

tempDist = np.sum((X-Centroids[:,0])**2,axis=1)
tempDist
# Out:
# array([0.00576406, 0.00613335, 0.00527058, ..., 0.00191849, 0.00253604,
#        0.00148986])

# %%
for k in range(K): 
    tempDist=np.sum((X-Centroids[:,k])**2,axis=1)
    EuclidianDistance=np.c_[EuclidianDistance,tempDist]
EuclidianDistance.shape
# Out:
# (7700, 25)

# %%
np.argmin(EuclidianDistance,axis=1)
# Out:
# array([15, 18, 18, ...,  1,  2, 23])

# %%
# 0부터 시작하므로 보기 편하기 위해 1을 더해서 만들어줌 ( 성능에 의미는 없음 편하게 그냥 만들어봄 )
C=np.argmin(EuclidianDistance,axis=1)+1 
C
# Out:
# array([16, 19, 19, ...,  2,  3, 24])

# %%
Y={}
for k in range(K): 
    Y[k+1]=np.array([]).reshape(136,0) # 특징 개수
Y
# Out:
# {1: array([], shape=(136, 0), dtype=float64),
#  2: array([], shape=(136, 0), dtype=float64),
#  3: array([], shape=(136, 0), dtype=float64),
#  4: array([], shape=(136, 0), dtype=float64),
#  5: array([], shape=(136, 0), dtype=float64),
#  6: array([], shape=(136, 0), dtype=float64),
#  7: array([], shape=(136, 0), dtype=float64),
#  8: array([], shape=(136, 0), dtype=float64),
#  9: array([], shape=(136, 0), dtype=float64),
#  10: array([], shape=(136, 0), dtype=float64),
#  11: array([], shape=(136, 0), dtype=float64),
#  12: array([], shape=(136, 0), dtype=float64),
#  13: array([], shape=(136, 0), dtype=float64),
#  14: array([], shape=(136, 0), dtype=float64),
#  15: array([], shape=(136, 0), dtype=float64),
#  16: array([], shape=(136, 0), dtype=float64),
#  17: array([], shape=(136, 0), dtype=float64),
#  18: array([], shape=(136, 0), dtype=float64),
#  19: array([], shape=(136, 0), dtype=float64),
#  20: array([], shape=(136, 0), dtype=float64),
#  21: array([], shape=(136, 0), dtype=float64),
#  22: array([], shape=(136, 0), dtype=float64),
#  23: array([], shape=(136, 0), dtype=float64),
#  24: array([], shape=(136, 0), dtype=float64),
#  25: array([], shape=(136, 0), dtype=float64)}

# %%
Y[C[0]]=np.c_[Y[C[0]],X[0]]
Y[C[0]]
# Out:
# array([[0.0304163 ],
#        [0.0051553 ],
#        [0.00438201],
#        [0.0136616 ],
#        [0.0141771 ],
#        [0.00979508],
#        [0.00412424],
#        [0.0171414 ],
#        [0.00154659],
#        [0.00554195],
#        [0.0162392 ],
#        [0.00476866],
#        [0.0119861 ],
#        [0.00347983],
#        [0.00786184],
#        [0.00799072],
#        [0.00773296],
#        [0.00206212],
#        [0.00605748],
#        [0.00618636],
#        [0.0105684 ],
#        [0.00541307],
#        [0.0103106 ],
#        [0.0103106 ],
#        [0.00605748],
#        [0.0105684 ],
#        [0.00799072],
#        [0.0123727 ],
#        [0.0051553 ],
#        [0.00631525],
#        [0.0100528 ],
#        [0.00979508],
#        [0.010955  ],
#        [0.00605748],
#        [0.0106973 ],
#        [0.00657301],
#        [0.00412424],
#        [0.00605748],
#        [0.00631525],
#        [0.00734631],
#        [0.00451089],
#        [0.00966619],
#        [0.00463977],
#        [0.00554195],
#        [0.0081196 ],
#        [0.00090218],
#        [0.00567083],
#        [0.00541307],
#        [0.00335095],
#        [0.00360871],
#        [0.00283542],
#        [0.00670189],
#        [0.00386648],
#        [0.00837737],
#        [0.00760407],
#        [0.00747519],
#        [0.0081196 ],
#        [0.00734631],
#        [0.00399536],
#        [0.00554195],
#        [0.00554195],
#        [0.00747519],
#        [0.00708854],
#        [0.00799072],
#        [0.0037376 ],
#        [0.0104395 ],
#        [0.0081196 ],
#        [0.00605748],
#        [0.00695966],
#        [0.0148215 ],
#        [0.00876402],
#        [0.00915066],
#        [0.00644413],
#        [0.00451089],
#        [0.0103106 ],
#        [0.00541307],
#        [0.00631525],
#        [0.00528419],
#        [0.00193324],
#        [0.00451089],
#        [0.00476866],
#        [0.00824849],
#        [0.00618636],
#        [0.00631525],
#        [0.00180436],
#        [0.00489754],
#        [0.00463977],
#        [0.00708854],
#        [0.00579972],
#        [0.0141771 ],
#        [0.00528419],
#        [0.0122438 ],
#        [0.00618636],
#        [0.00347983],
#        [0.00605748],
#        [0.00541307],
#        [0.00657301],
#        [0.00747519],
#        [0.00283542],
#        [0.00425313],
#        [0.00927955],
#        [0.0051553 ],
#        [0.0113417 ],
#        [0.00554195],
#        [0.00541307],
#        [0.012115  ],
#        [0.00747519],
#        [0.0059286 ],
#        [0.0051553 ],
#        [0.00476866],
#        [0.00541307],
#        [0.00231989],
#        [0.00966619],
#        [0.00902178],
#        [0.00567083],
#        [0.00476866],
#        [0.0181724 ],
#        [0.00915066],
#        [0.0132749 ],
#        [0.00463977],
#        [0.0104395 ],
#        [0.013146  ],
#        [0.00670189],
#        [0.0103106 ],
#        [0.00683078],
#        [0.00347983],
#        [0.00567083],
#        [0.00322206],
#        [0.00644413],
#        [0.00747519],
#        [0.0152081 ],
#        [0.00747519],
#        [0.00476866],
#        [0.0132749 ],
#        [0.00786184],
#        [0.002191  ]])

# %%
# 모든 데이터에 대해 반복
for i in range(m): 
    Y[C[i]]=np.c_[Y[C[i]],X[i]]
Y
# Out:
# {1: array([[0.00191769, 0.00315706, 0.00222603, ..., 0.00265191, 0.00192215,
#          0.00213163],
#         [0.00855583, 0.00868193, 0.0101027 , ..., 0.00818633, 0.00704789,
#          0.0106581 ],
#         [0.00457295, 0.00584057, 0.00530822, ..., 0.00449671, 0.00480538,
#          0.00253131],
#         ...,
#         [0.00811329, 0.00615627, 0.00702055, ..., 0.00772512, 0.00864969,
#          0.00799361],
#         [0.0041304 , 0.00568272, 0.00462329, ..., 0.00438141, 0.00400449,
#          0.00439648],
#         [0.00811329, 0.00694554, 0.00684932, ..., 0.00760982, 0.00897005,
#          0.00786038]]),
#  2: array([[0.00217967, 0.00243027, 0.00314882, ..., 0.00181196, 0.00405227,
#          0.00414479],
#         [0.0112097 , 0.010184  , 0.00911501, ..., 0.00845581, 0.0104346 ,
#          0.0132633 ],
#         [0.00591624, 0.00439764, 0.00198873, ..., 0.00442923, 0.00233006,
#          0.0020724 ],
#         ...,
#         [0.00685038, 0.00682791, 0.00994365, ..., 0.00845581, 0.00790193,
#          0.00400663],
#         [0.00467071, 0.00532346, 0.00281737, ..., 0.00543588, 0.00354574,
#          0.00331583],
#         [0.010587  , 0.00937392, 0.0117667 , ..., 0.00926112, 0.014183  ,
#          0.012987  ]]),
#  3: array([[0.00412302, 0.00768131, 0.0017268 , ..., 0.00589797, 0.002226  ,
#          0.00397151],
#         [0.010029  , 0.00937835, 0.0140871 , ..., 0.00442347, 0.0146654 ,
#          0.00917557],
#         [0.00713171, 0.00687746, 0.00608925, ..., 0.00353878, 0.00589237,
#          0.00903862],
#         ...,
#         [0.00546022, 0.0050911 , 0.00654367, ..., 0.00737246, 0.00445201,
#          0.005341  ],
#         [0.00902608, 0.00857449, 0.00608925, ..., 0.00353878, 0.00419013,
#          0.00958641],
#         [0.00846891, 0.0081279 , 0.00472598, ..., 0.00442347, 0.00602331,
#          0.00890167]]),
#  4: array([[0.00718042, 0.0068692 , 0.0110218 , ..., 0.00870406, 0.00709861,
#          0.00809661],
#         [0.00960761, 0.00861068, 0.00849598, ..., 0.0070922 , 0.0082602 ,
#          0.005352  ],
#         [0.0049555 , 0.00425697, 0.00482204, ..., 0.0046744 , 0.00425916,
#          0.0049403 ],
#         ...,
#         [0.0126416 , 0.0109327 , 0.0101033 , ..., 0.00934881, 0.0113578 ,
#          0.0130369 ],
#         [0.00444984, 0.00474071, 0.00413318, ..., 0.00402966, 0.00464636,
#          0.00617538],
#         [0.0052589 , 0.00474071, 0.00459242, ..., 0.00322373, 0.00464636,
#          0.00603815]]),
#  5: array([[0.0274379 , 0.0216395 , 0.0208165 , ..., 0.0219389 , 0.02992   ,
#          0.0251621 ],
#         [0.00380093, 0.00623842, 0.00707357, ..., 0.00412526, 0.00257931,
#          0.00186793],
#         [0.00570139, 0.00477629, 0.0051536 , ..., 0.0048753 , 0.00386897,
#          0.00571366],
#         ...,
#         [0.0108089 , 0.00867531, 0.00919563, ..., 0.0132196 , 0.0100593 ,
#          0.00911988],
#         [0.00617651, 0.00740813, 0.00959984, ..., 0.00618789, 0.00696415,
#          0.00714207],
#         [0.00130657, 0.00419144, 0.00505255, ..., 0.0031877 , 0.00128966,
#          0.00153829]]),
#  6: array([[0.00331813, 0.00791264, 0.00318345, ..., 0.00213134, 0.00428844,
#          0.00626834],
#         [0.0100373 , 0.00775439, 0.0121369 , ..., 0.00852538, 0.0071474 ,
#          0.00960256],
#         [0.00555786, 0.00712138, 0.00567051, ..., 0.00599441, 0.00444727,
#          0.00506802],
#         ...,
#         [0.00779759, 0.00775439, 0.00676482, ..., 0.00679366, 0.00746506,
#          0.00840224],
#         [0.00497719, 0.00553885, 0.00487465, ..., 0.00626082, 0.00540025,
#          0.00506802],
#         [0.00945666, 0.00743789, 0.00218862, ..., 0.008925  , 0.00603558,
#          0.00573486]]),
#  7: array([[0.0202732 , 0.0190966 , 0.013551  , ..., 0.0233386 , 0.0208821 ,
#          0.0179098 ],
#         [0.00583298, 0.00306035, 0.00338774, ..., 0.00454905, 0.00585059,
#          0.00453412],
#         [0.0039835 , 0.00538622, 0.00769941, ..., 0.00712025, 0.00549055,
#          0.00793471],
#         ...,
#         [0.0133732 , 0.00967071, 0.00800739, ..., 0.0102848 , 0.010441  ,
#          0.00884153],
#         [0.00355669, 0.00563104, 0.00739144, ..., 0.00632911, 0.00549055,
#          0.003854  ],
#         [0.00177835, 0.00428449, 0.00554358, ..., 0.00197785, 0.00171017,
#          0.00113353]]),
#  8: array([[0.00083738, 0.00202888, 0.0025012 , ..., 0.00225989, 0.00254079,
#          0.00210284],
#         [0.01725   , 0.0159924 , 0.0152958 , ..., 0.0170904 , 0.0155122 ,
#          0.0153982 ],
#         [0.00485681, 0.00656403, 0.00654161, ..., 0.0049435 , 0.00508157,
#          0.00630851],
#         ...,
#         [0.00435438, 0.00477384, 0.00557961, ..., 0.00466102, 0.00494785,
#          0.00603717],
#         [0.00200971, 0.00584795, 0.00615681, ..., 0.00649718, 0.00441294,
#          0.00481617],
#         [0.00602914, 0.00895095, 0.00836941, ..., 0.0132768 , 0.00855844,
#          0.00902184]]),
#  9: array([[0.0227493 , 0.0166836 , 0.016335  , ..., 0.0201981 , 0.0304331 ,
#          0.0282643 ],
#         [0.00556631, 0.00681851, 0.003861  , ..., 0.00485531, 0.00496089,
#          0.00496205],
#         [0.00580833, 0.00304657, 0.004752  , ..., 0.00271897, 0.00448388,
#          0.00549718],
#         ...,
#         [0.0116167 , 0.0123314 , 0.016632  , ..., 0.0134007 , 0.012593  ,
#          0.0137673 ],
#         [0.00738141, 0.00333672, 0.00504901, ..., 0.00407846, 0.00686892,
#          0.00647013],
#         [0.00096805, 0.00203105, 0.002376  , ..., 0.00174791, 0.00133562,
#          0.00082701]]),
#  10: array([[0.0307284 , 0.030739  , 0.0304847 , ..., 0.0327318 , 0.0338851 ,
#          0.0324895 ],
#         [0.00379363, 0.00327011, 0.00530169, ..., 0.00497822, 0.00437227,
#          0.00473805],
#         [0.00474203, 0.00555919, 0.00403938, ..., 0.00696951, 0.00468457,
#          0.00365507],
#         ...,
#         [0.0123293 , 0.00735775, 0.0136329 , ..., 0.00721842, 0.0126483 ,
#          0.0111006 ],
#         [0.00796662, 0.0088293 , 0.00807877, ..., 0.00734287, 0.00874453,
#          0.00703939],
#         [0.00379363, 0.00490517, 0.00271396, ..., 0.0022402 , 0.00187383,
#          0.0014891 ]]),
#  11: array([[0.00403458, 0.00154668, 0.00099483, ..., 0.00162778, 0.00248499,
#          0.00284559],
#         [0.015562  , 0.014342  , 0.0132312 , ..., 0.0127509 , 0.0122179 ,
#          0.0125805 ],
#         [0.00691643, 0.00506187, 0.00368086, ..., 0.00515464, 0.00559122,
#          0.00554141],
#         ...,
#         [0.00518732, 0.00337458, 0.00616793, ..., 0.0127509 , 0.00559122,
#          0.00554141],
#         [0.00288184, 0.00506187, 0.00397931, ..., 0.00406945, 0.00455581,
#          0.00389396],
#         [0.00634006, 0.00674916, 0.00726224, ..., 0.00569723, 0.00559122,
#          0.00703909]]),
#  12: array([[0.039313  , 0.0315781 , 0.0271563 , ..., 0.0580184 , 0.0387344 ,
#          0.0338274 ],
#         [0.00209924, 0.00203467, 0.00200586, ..., 0.00102145, 0.00153404,
#          0.00196814],
#         [0.00629771, 0.00463905, 0.00678908, ..., 0.00429009, 0.00402685,
#          0.0055969 ],
#         ...,
#         [0.0127863 , 0.00960365, 0.00894924, ..., 0.0100102 , 0.0113135 ,
#          0.0107018 ],
#         [0.00381679, 0.0049646 , 0.00632618, ..., 0.00367722, 0.00479386,
#          0.00541239],
#         [0.        , 0.00024416, 0.0001543 , ..., 0.        , 0.        ,
#          0.00024602]]),
#  13: array([[0.017118  , 0.0102801 , 0.0141977 , ..., 0.0197516 , 0.0166423 ,
#          0.0131224 ],
#         [0.00659464, 0.00898494, 0.00482186, ..., 0.00733048, 0.00603511,
#          0.00575229],
#         [0.00378841, 0.00501862, 0.00803643, ..., 0.00447974, 0.0046635 ,
#          0.00611181],
#         ...,
#         [0.0116459 , 0.00995629, 0.00964372, ..., 0.0103849 , 0.0103328 ,
#          0.0100665 ],
#         [0.008559  , 0.00825644, 0.011251  , ..., 0.00794136, 0.00685808,
#          0.0107855 ],
#         [0.00673495, 0.00696131, 0.00535762, ..., 0.00570149, 0.00438917,
#          0.00575229]]),
#  14: array([[0.0201234 , 0.02283   , 0.0238186 , ..., 0.0232769 , 0.0229592 ,
#          0.0196261 ],
#         [0.00364041, 0.00678119, 0.00341621, ..., 0.00362085, 0.00440631,
#          0.00392522],
#         [0.00566286, 0.00248644, 0.00389068, ..., 0.00452606, 0.00347866,
#          0.00578804],
#         ...,
#         [0.0120336 , 0.0137884 , 0.0105333 , ..., 0.0129316 , 0.0141466 ,
#          0.0120418 ],
#         [0.00616847, 0.00474684, 0.00759157, ..., 0.00711238, 0.00463822,
#          0.0059211 ],
#         [0.00222469, 0.00248644, 0.00189789, ..., 0.002457  , 0.00347866,
#          0.00153017]]),
#  15: array([[0.0120979 , 0.0197003 , 0.0180871 , ..., 0.0191423 , 0.0128929 ,
#          0.017233  ],
#         [0.00612013, 0.0047146 , 0.00636666, ..., 0.00630949, 0.0078578 ,
#          0.00706748],
#         [0.0029889 , 0.00488298, 0.00274924, ..., 0.00513314, 0.00549283,
#          0.00493755],
#         ...,
#         [0.011244  , 0.0102711 , 0.0134568 , ..., 0.0110149 , 0.0107568 ,
#          0.011521  ],
#         [0.00740108, 0.00690352, 0.0094053 , ..., 0.00876912, 0.00823924,
#          0.00890696],
#         [0.0059778 , 0.00589325, 0.00853711, ..., 0.00641643, 0.00625572,
#          0.00513118]]),
#  16: array([[0.0304163 , 0.0304163 , 0.0237113 , ..., 0.0183746 , 0.020467  ,
#          0.0222628 ],
#         [0.0051553 , 0.0051553 , 0.00701031, ..., 0.00665927, 0.00700549,
#          0.00498422],
#         [0.00438201, 0.00438201, 0.0043299 , ..., 0.00505611, 0.00659341,
#          0.00498422],
#         ...,
#         [0.0132749 , 0.0132749 , 0.0117526 , ..., 0.00752251, 0.0131868 ,
#          0.0119621 ],
#         [0.00786184, 0.00786184, 0.00783505, ..., 0.0110988 , 0.00673077,
#          0.00647948],
#         [0.002191  , 0.002191  , 0.00226804, ..., 0.0108521 , 0.00288462,
#          0.00299053]]),
#  17: array([[0.00068132, 0.00205011, 0.00290084, ..., 0.00350175, 0.00206996,
#          0.00290314],
#         [0.0178845 , 0.0150342 , 0.0158228 , ..., 0.014007  , 0.0146968 ,
#          0.0149116 ],
#         [0.00289559, 0.00455581, 0.00474684, ..., 0.00550275, 0.00455392,
#          0.00475059],
#         ...,
#         [0.00425822, 0.00410023, 0.0039557 , ..., 0.002001  , 0.00372594,
#          0.00554236],
#         [0.00391756, 0.00523918, 0.00632911, ..., 0.004002  , 0.00496792,
#          0.00435471],
#         [0.0122637 , 0.00842825, 0.0105485 , ..., 0.0110055 , 0.0117988 ,
#          0.00725785]]),
#  18: array([[0.00257247, 0.00367692, 0.00519903, ..., 0.00257239, 0.00578953,
#          0.00284143],
#         [0.0144454 , 0.0132369 , 0.00909829, ..., 0.0137439 , 0.0072653 ,
#          0.0126489 ],
#         [0.00544177, 0.00551538, 0.00454915, ..., 0.00617375, 0.00613009,
#          0.00504125],
#         ...,
#         [0.00633224, 0.00539282, 0.00796101, ..., 0.00529178, 0.0089681 ,
#          0.00577452],
#         [0.00385871, 0.00661846, 0.00568643, ..., 0.00536528, 0.00681122,
#          0.00531622],
#         [0.0074206 , 0.00821179, 0.00552396, ..., 0.00852565, 0.00476785,
#          0.00889093]]),
#  19: array([[0.0252953 , 0.0266104 , 0.0241271 , ..., 0.0235149 , 0.0216903 ,
#          0.0245098 ],
#         [0.0043187 , 0.00440448, 0.00543478, ..., 0.00461296, 0.00578984,
#          0.00442758],
#         [0.00414243, 0.00513856, 0.00395257, ..., 0.00393789, 0.00440719,
#          0.00553447],
#         ...,
#         [0.00995946, 0.00991008, 0.00864625, ..., 0.00855086, 0.0103699 ,
#          0.0085389 ],
#         [0.00749163, 0.00789136, 0.00617589, ..., 0.00832583, 0.0110612 ,
#          0.00790639],
#         [0.00326106, 0.00440448, 0.00329381, ..., 0.0069757 , 0.00622191,
#          0.00458571]]),
#  20: array([[0.016708  , 0.00653839, 0.0161978 , ..., 0.00844416, 0.0085138 ,
#          0.00933689],
#         [0.00661704, 0.00597796, 0.0057351 , ..., 0.0079164 , 0.0075219 ,
#          0.0070503 ],
#         [0.00215054, 0.00261536, 0.00317756, ..., 0.00401098, 0.00380228,
#          0.00609756],
#         ...,
#         [0.0122415 , 0.0106482 , 0.0110052 , ..., 0.0120329 , 0.00991899,
#          0.00876524],
#         [0.00264682, 0.00560433, 0.00434008, ..., 0.00559426, 0.00479418,
#          0.00457317],
#         [0.00231596, 0.00410984, 0.00248004, ..., 0.0050665 , 0.00421557,
#          0.00495427]]),
#  21: array([[0.00186472, 0.00054338, 0.00686197, ..., 0.00119952, 0.00075075,
#          0.00048368],
#         [0.0142397 , 0.0188372 , 0.0147796 , ..., 0.019992  , 0.0176426 ,
#          0.0169287 ],
#         [0.00508561, 0.00434704, 0.00527844, ..., 0.00719712, 0.00600601,
#          0.00677146],
#         ...,
#         [0.00491609, 0.00380366, 0.00475059, ..., 0.00279888, 0.00187688,
#          0.00411125],
#         [0.00406849, 0.00307915, 0.00422275, ..., 0.00679728, 0.00638138,
#          0.00677146],
#         [0.00915409, 0.01286   , 0.00580628, ..., 0.0121951 , 0.00788288,
#          0.00652963]]),
#  22: array([[0.0326425 , 0.0280973 , 0.0243709 , ..., 0.0294118 , 0.0238679 ,
#          0.0394122 ],
#         [0.00414508, 0.00435426, 0.00369523, ..., 0.00527903, 0.00309004,
#          0.00267201],
#         [0.00362694, 0.00517581, 0.0052789 , ..., 0.00490196, 0.00447523,
#          0.00400802],
#         ...,
#         [0.0100173 , 0.00953007, 0.00888615, ..., 0.0120664 , 0.0136388 ,
#          0.00734803],
#         [0.00673575, 0.00607953, 0.00659863, ..., 0.00641026, 0.00735216,
#          0.00601202],
#         [0.00345423, 0.00156096, 0.00123174, ..., 0.00226244, 0.00287693,
#          0.00334001]]),
#  23: array([[0.00610084, 0.00233309, 0.00601436, ..., 0.00726141, 0.00644522,
#          0.00919003],
#         [0.00789521, 0.0131012 , 0.00816876, ..., 0.00715768, 0.00991572,
#          0.0088785 ],
#         [0.00466535, 0.00664034, 0.0043088 , ..., 0.00705394, 0.00644522,
#          0.00498442],
#         ...,
#         [0.00843352, 0.0154343 , 0.0124776 , ..., 0.00943983, 0.00495786,
#          0.0105919 ],
#         [0.00484479, 0.00879397, 0.0051167 , ..., 0.00674274, 0.00644522,
#          0.00373832],
#         [0.00628028, 0.00484566, 0.00520646, ..., 0.00404564, 0.006941  ,
#          0.00545171]]),
#  24: array([[0.0153588 , 0.0169727 , 0.0118256 , ..., 0.0125275 , 0.0143481 ,
#          0.0115848 ],
#         [0.00559955, 0.00639955, 0.00622954, ..., 0.00608978, 0.0062383 ,
#          0.00676863],
#         [0.00463963, 0.00454461, 0.00295639, ..., 0.00411785, 0.00311915,
#          0.00488122],
#         ...,
#         [0.00991921, 0.0106659 , 0.00981945, ..., 0.00980165, 0.0066126 ,
#          0.00904653],
#         [0.0074394 , 0.00779076, 0.00770774, ..., 0.00655376, 0.00935745,
#          0.00859095],
#         [0.00487961, 0.00547208, 0.00644071, ..., 0.00603178, 0.00935745,
#          0.00670355]]),
#  25: array([[0.00145173, 0.00097034, 0.00088329, ..., 0.00213432, 0.00141203,
#          0.00176678],
#         [0.0166949 , 0.0159412 , 0.0151264 , ..., 0.0169323 , 0.0129907 ,
#          0.0169403 ],
#         [0.00677474, 0.00693097, 0.00518936, ..., 0.00540694, 0.0048009 ,
#          0.00488464],
#         ...,
#         [0.00629083, 0.00512892, 0.0046373 , ..., 0.00583381, 0.00734256,
#          0.00519642],
#         [0.0048391 , 0.00485168, 0.00353318, ..., 0.0035572 , 0.00790737,
#          0.00488464],
#         [0.00919429, 0.0103965 , 0.0133598 , ..., 0.00967558, 0.00988421,
#          0.00966535]])}

# %%
for i in range(n_iter): # n_iter 반복 횟수
   
    EuclidianDistance=np.array([]).reshape(m,0)
    for k in range(K):
        tempDist=np.sum((X-Centroids[:,k])**2,axis=1) 
        EuclidianDistance=np.c_[EuclidianDistance,tempDist] 
    C=np.argmin(EuclidianDistance,axis=1)+1 
    # K 클러스터 갱신
    Y={}
    for k in range(K):
        Y[k+1]=np.array([]).reshape(136,0) # Y 딕셔너리 키, 값 할당
    for i in range(m):
        Y[C[i]]=np.c_[Y[C[i]],X[i]] # Y 딕셔너리 키(K클러스터), 값(vi, ho) 할당
    for k in range(K):
        Y[k+1]=Y[k+1].T # 전치행렬
    for k in range(K):
        Centroids[:,k]=np.mean(Y[k+1],axis=0) # K 클러스터 중심 갱신
    Output=Y

# %%
print(Output[2].shape)
cnt=0

for k in range(1,K): 
    print("Clustering",k,"개수 ",len(Output[k]))
    for i in range(len(Output[k])): 
        
        for a in range(m):

            if np.array_equal(vi[a],Output[k][i]) == True:

                print("vi[",k,"] == Output[",k ,"][", i,"]")
                cnt+=1
print(cnt)
# Out:
# (571, 136)
# Clustering 1 개수  381
# vi[ 1 ] == Output[ 1 ][ 0 ]
# vi[ 1 ] == Output[ 1 ][ 1 ]
# vi[ 1 ] == Output[ 1 ][ 2 ]
# vi[ 1 ] == Output[ 1 ][ 3 ]
# vi[ 1 ] == Output[ 1 ][ 4 ]
# vi[ 1 ] == Output[ 1 ][ 5 ]
# vi[ 1 ] == Output[ 1 ][ 6 ]
# vi[ 1 ] == Output[ 1 ][ 7 ]
# vi[ 1 ] == Output[ 1 ][ 8 ]
# vi[ 1 ] == Output[ 1 ][ 9 ]
# vi[ 1 ] == Output[ 1 ][ 10 ]
# vi[ 1 ] == Output[ 1 ][ 11 ]
# vi[ 1 ] == Output[ 1 ][ 12 ]
# vi[ 1 ] == Output[ 1 ][ 13 ]
# vi[ 1 ] == Output[ 1 ][ 14 ]
# vi[ 1 ] == Output[ 1 ][ 15 ]
# vi[ 1 ] == Output[ 1 ][ 16 ]
# vi[ 1 ] == Output[ 1 ][ 17 ]
# vi[ 1 ] == Output[ 1 ][ 18 ]
# vi[ 1 ] == Output[ 1 ][ 19 ]
# vi[ 1 ] == Output[ 1 ][ 20 ]
# vi[ 1 ] == Output[ 1 ][ 21 ]
# vi[ 1 ] == Output[ 1 ][ 22 ]
# vi[ 1 ] == Output[ 1 ][ 23 ]
# vi[ 1 ] == Output[ 1 ][ 24 ]
# vi[ 1 ] == Output[ 1 ][ 25 ]
# vi[ 1 ] == Output[ 1 ][ 26 ]
# vi[ 1 ] == Output[ 1 ][ 27 ]
# vi[ 1 ] == Output[ 1 ][ 28 ]
# vi[ 1 ] == Output[ 1 ][ 29 ]
# vi[ 1 ] == Output[ 1 ][ 30 ]
# vi[ 1 ] == Output[ 1 ][ 31 ]
# vi[ 1 ] == Output[ 1 ][ 32 ]
# vi[ 1 ] == Output[ 1 ][ 33 ]
# vi[ 1 ] == Output[ 1 ][ 34 ]
# vi[ 1 ] == Output[ 1 ][ 35 ]
# vi[ 1 ] == Output[ 1 ][ 36 ]
# vi[ 1 ] == Output[ 1 ][ 37 ]
# vi[ 1 ] == Output[ 1 ][ 38 ]
# vi[ 1 ] == Output[ 1 ][ 39 ]
# vi[ 1 ] == Output[ 1 ][ 40 ]
# vi[ 1 ] == Output[ 1 ][ 41 ]
# vi[ 1 ] == Output[ 1 ][ 42 ]
# vi[ 1 ] == Output[ 1 ][ 43 ]
# vi[ 1 ] == Output[ 1 ][ 44 ]
# vi[ 1 ] == Output[ 1 ][ 45 ]
# vi[ 1 ] == Output[ 1 ][ 46 ]
# vi[ 1 ] == Output[ 1 ][ 47 ]
# vi[ 1 ] == Output[ 1 ][ 48 ]
# vi[ 1 ] == Output[ 1 ][ 49 ]
# vi[ 1 ] == Output[ 1 ][ 50 ]
# vi[ 1 ] == Output[ 1 ][ 51 ]
# vi[ 1 ] == Output[ 1 ][ 52 ]
# vi[ 1 ] == Output[ 1 ][ 53 ]
# vi[ 1 ] == Output[ 1 ][ 54 ]
# vi[ 1 ] == Output[ 1 ][ 55 ]
# vi[ 1 ] == Output[ 1 ][ 56 ]
# vi[ 1 ] == Output[ 1 ][ 57 ]
# vi[ 1 ] == Output[ 1 ][ 58 ]
# vi[ 1 ] == Output[ 1 ][ 59 ]
# vi[ 1 ] == Output[ 1 ][ 60 ]
# vi[ 1 ] == Output[ 1 ][ 61 ]
# vi[ 1 ] == Output[ 1 ][ 62 ]
# vi[ 1 ] == Output[ 1 ][ 63 ]
# vi[ 1 ] == Output[ 1 ][ 64 ]
# vi[ 1 ] == Output[ 1 ][ 65 ]
# vi[ 1 ] == Output[ 1 ][ 66 ]
# vi[ 1 ] == Output[ 1 ][ 67 ]
# vi[ 1 ] == Output[ 1 ][ 68 ]
# vi[ 1 ] == Output[ 1 ][ 69 ]
# vi[ 1 ] == Output[ 1 ][ 70 ]
# vi[ 1 ] == Output[ 1 ][ 71 ]
# vi[ 1 ] == Output[ 1 ][ 72 ]
# vi[ 1 ] == Output[ 1 ][ 73 ]
# vi[ 1 ] == Output[ 1 ][ 74 ]
# vi[ 1 ] == Output[ 1 ][ 75 ]
# vi[ 1 ] == Output[ 1 ][ 76 ]
# vi[ 1 ] == Output[ 1 ][ 77 ]
# vi[ 1 ] == Output[ 1 ][ 78 ]
# vi[ 1 ] == Output[ 1 ][ 79 ]
# vi[ 1 ] == Output[ 1 ][ 80 ]
# vi[ 1 ] == Output[ 1 ][ 81 ]
# vi[ 1 ] == Output[ 1 ][ 82 ]
# vi[ 1 ] == Output[ 1 ][ 83 ]
# vi[ 1 ] == Output[ 1 ][ 84 ]
# vi[ 1 ] == Output[ 1 ][ 85 ]
# vi[ 1 ] == Output[ 1 ][ 86 ]
# vi[ 1 ] == Output[ 1 ][ 87 ]
# vi[ 1 ] == Output[ 1 ][ 88 ]
# vi[ 1 ] == Output[ 1 ][ 89 ]
# vi[ 1 ] == Output[ 1 ][ 90 ]
# vi[ 1 ] == Output[ 1 ][ 91 ]
# vi[ 1 ] == Output[ 1 ][ 92 ]
# vi[ 1 ] == Output[ 1 ][ 93 ]
# vi[ 1 ] == Output[ 1 ][ 94 ]
# vi[ 1 ] == Output[ 1 ][ 95 ]
# vi[ 1 ] == Output[ 1 ][ 96 ]
# vi[ 1 ] == Output[ 1 ][ 97 ]
# vi[ 1 ] == Output[ 1 ][ 98 ]
# vi[ 1 ] == Output[ 1 ][ 99 ]
# vi[ 1 ] == Output[ 1 ][ 100 ]
# vi[ 1 ] == Output[ 1 ][ 101 ]
# vi[ 1 ] == Output[ 1 ][ 102 ]
# vi[ 1 ] == Output[ 1 ][ 103 ]
# vi[ 1 ] == Output[ 1 ][ 104 ]
# vi[ 1 ] == Output[ 1 ][ 105 ]
# vi[ 1 ] == Output[ 1 ][ 106 ]
# vi[ 1 ] == Output[ 1 ][ 107 ]
# vi[ 1 ] == Output[ 1 ][ 108 ]
# vi[ 1 ] == Output[ 1 ][ 109 ]
# vi[ 1 ] == Output[ 1 ][ 110 ]
# vi[ 1 ] == Output[ 1 ][ 111 ]
# vi[ 1 ] == Output[ 1 ][ 112 ]
# vi[ 1 ] == Output[ 1 ][ 113 ]
# vi[ 1 ] == Output[ 1 ][ 114 ]
# vi[ 1 ] == Output[ 1 ][ 115 ]
# vi[ 1 ] == Output[ 1 ][ 116 ]
# vi[ 1 ] == Output[ 1 ][ 117 ]
# vi[ 1 ] == Output[ 1 ][ 118 ]
# vi[ 1 ] == Output[ 1 ][ 119 ]
# vi[ 1 ] == Output[ 1 ][ 120 ]
# vi[ 1 ] == Output[ 1 ][ 121 ]
# vi[ 1 ] == Output[ 1 ][ 122 ]
# vi[ 1 ] == Output[ 1 ][ 123 ]
# vi[ 1 ] == Output[ 1 ][ 124 ]
# vi[ 1 ] == Output[ 1 ][ 125 ]
# vi[ 1 ] == Output[ 1 ][ 126 ]
# vi[ 1 ] == Output[ 1 ][ 127 ]
# vi[ 1 ] == Output[ 1 ][ 128 ]
# vi[ 1 ] == Output[ 1 ][ 129 ]
# vi[ 1 ] == Output[ 1 ][ 130 ]
# vi[ 1 ] == Output[ 1 ][ 131 ]
# vi[ 1 ] == Output[ 1 ][ 132 ]
# vi[ 1 ] == Output[ 1 ][ 133 ]
# vi[ 1 ] == Output[ 1 ][ 134 ]
# vi[ 1 ] == Output[ 1 ][ 135 ]
# vi[ 1 ] == Output[ 1 ][ 136 ]
# vi[ 1 ] == Output[ 1 ][ 137 ]
# vi[ 1 ] == Output[ 1 ][ 138 ]
# vi[ 1 ] == Output[ 1 ][ 139 ]
# vi[ 1 ] == Output[ 1 ][ 140 ]
# vi[ 1 ] == Output[ 1 ][ 141 ]
# vi[ 1 ] == Output[ 1 ][ 142 ]
# vi[ 1 ] == Output[ 1 ][ 143 ]
# vi[ 1 ] == Output[ 1 ][ 144 ]
# vi[ 1 ] == Output[ 1 ][ 145 ]
# vi[ 1 ] == Output[ 1 ][ 146 ]
# vi[ 1 ] == Output[ 1 ][ 147 ]
# vi[ 1 ] == Output[ 1 ][ 148 ]
# vi[ 1 ] == Output[ 1 ][ 149 ]
# vi[ 1 ] == Output[ 1 ][ 150 ]
# vi[ 1 ] == Output[ 1 ][ 151 ]
# vi[ 1 ] == Output[ 1 ][ 152 ]
# vi[ 1 ] == Output[ 1 ][ 153 ]
# vi[ 1 ] == Output[ 1 ][ 154 ]
# vi[ 1 ] == Output[ 1 ][ 155 ]
# vi[ 1 ] == Output[ 1 ][ 156 ]
# vi[ 1 ] == Output[ 1 ][ 157 ]
# vi[ 1 ] == Output[ 1 ][ 158 ]
# vi[ 1 ] == Output[ 1 ][ 159 ]
# vi[ 1 ] == Output[ 1 ][ 160 ]
# vi[ 1 ] == Output[ 1 ][ 161 ]
# vi[ 1 ] == Output[ 1 ][ 162 ]
# vi[ 1 ] == Output[ 1 ][ 163 ]
# vi[ 1 ] == Output[ 1 ][ 164 ]
# vi[ 1 ] == Output[ 1 ][ 165 ]
# vi[ 1 ] == Output[ 1 ][ 166 ]
# vi[ 1 ] == Output[ 1 ][ 167 ]
# vi[ 1 ] == Output[ 1 ][ 168 ]
# vi[ 1 ] == Output[ 1 ][ 169 ]
# vi[ 1 ] == Output[ 1 ][ 170 ]
# vi[ 1 ] == Output[ 1 ][ 171 ]
# vi[ 1 ] == Output[ 1 ][ 172 ]
# vi[ 1 ] == Output[ 1 ][ 173 ]
# vi[ 1 ] == Output[ 1 ][ 174 ]
# vi[ 1 ] == Output[ 1 ][ 175 ]
# vi[ 1 ] == Output[ 1 ][ 176 ]
# vi[ 1 ] == Output[ 1 ][ 177 ]
# vi[ 1 ] == Output[ 1 ][ 178 ]
# vi[ 1 ] == Output[ 1 ][ 179 ]
# vi[ 1 ] == Output[ 1 ][ 180 ]
# vi[ 1 ] == Output[ 1 ][ 181 ]
# vi[ 1 ] == Output[ 1 ][ 182 ]
# vi[ 1 ] == Output[ 1 ][ 183 ]
# vi[ 1 ] == Output[ 1 ][ 184 ]
# vi[ 1 ] == Output[ 1 ][ 185 ]
# vi[ 1 ] == Output[ 1 ][ 186 ]
# vi[ 1 ] == Output[ 1 ][ 187 ]
# vi[ 1 ] == Output[ 1 ][ 188 ]
# vi[ 1 ] == Output[ 1 ][ 189 ]
# vi[ 1 ] == Output[ 1 ][ 190 ]
# vi[ 1 ] == Output[ 1 ][ 191 ]
# vi[ 1 ] == Output[ 1 ][ 192 ]
# vi[ 1 ] == Output[ 1 ][ 193 ]
# vi[ 1 ] == Output[ 1 ][ 194 ]
# vi[ 1 ] == Output[ 1 ][ 195 ]
# vi[ 1 ] == Output[ 1 ][ 196 ]
# vi[ 1 ] == Output[ 1 ][ 197 ]
# vi[ 1 ] == Output[ 1 ][ 198 ]
# vi[ 1 ] == Output[ 1 ][ 199 ]
# vi[ 1 ] == Output[ 1 ][ 200 ]
# vi[ 1 ] == Output[ 1 ][ 201 ]
# vi[ 1 ] == Output[ 1 ][ 202 ]
# vi[ 1 ] == Output[ 1 ][ 203 ]
# vi[ 1 ] == Output[ 1 ][ 204 ]
# vi[ 1 ] == Output[ 1 ][ 205 ]
# vi[ 1 ] == Output[ 1 ][ 206 ]
# vi[ 1 ] == Output[ 1 ][ 207 ]
# vi[ 1 ] == Output[ 1 ][ 208 ]
# vi[ 1 ] == Output[ 1 ][ 209 ]
# vi[ 1 ] == Output[ 1 ][ 210 ]
# vi[ 1 ] == Output[ 1 ][ 211 ]
# vi[ 1 ] == Output[ 1 ][ 212 ]
# vi[ 1 ] == Output[ 1 ][ 213 ]
# vi[ 1 ] == Output[ 1 ][ 214 ]
# vi[ 1 ] == Output[ 1 ][ 215 ]
# vi[ 1 ] == Output[ 1 ][ 216 ]
# vi[ 1 ] == Output[ 1 ][ 217 ]
# vi[ 1 ] == Output[ 1 ][ 218 ]
# vi[ 1 ] == Output[ 1 ][ 219 ]
# vi[ 1 ] == Output[ 1 ][ 220 ]
# vi[ 1 ] == Output[ 1 ][ 221 ]
# vi[ 1 ] == Output[ 1 ][ 222 ]
# vi[ 1 ] == Output[ 1 ][ 223 ]
# vi[ 1 ] == Output[ 1 ][ 224 ]
# vi[ 1 ] == Output[ 1 ][ 225 ]
# vi[ 1 ] == Output[ 1 ][ 226 ]
# vi[ 1 ] == Output[ 1 ][ 227 ]
# vi[ 1 ] == Output[ 1 ][ 228 ]
# vi[ 1 ] == Output[ 1 ][ 229 ]
# vi[ 1 ] == Output[ 1 ][ 230 ]
# vi[ 1 ] == Output[ 1 ][ 231 ]
# vi[ 1 ] == Output[ 1 ][ 232 ]
# vi[ 1 ] == Output[ 1 ][ 233 ]
# vi[ 1 ] == Output[ 1 ][ 234 ]
# vi[ 1 ] == Output[ 1 ][ 235 ]
# vi[ 1 ] == Output[ 1 ][ 236 ]
# vi[ 1 ] == Output[ 1 ][ 237 ]
# vi[ 1 ] == Output[ 1 ][ 238 ]
# vi[ 1 ] == Output[ 1 ][ 239 ]
# vi[ 1 ] == Output[ 1 ][ 240 ]
# vi[ 1 ] == Output[ 1 ][ 241 ]
# vi[ 1 ] == Output[ 1 ][ 242 ]
# vi[ 1 ] == Output[ 1 ][ 243 ]
# vi[ 1 ] == Output[ 1 ][ 244 ]
# vi[ 1 ] == Output[ 1 ][ 245 ]
# vi[ 1 ] == Output[ 1 ][ 246 ]
# vi[ 1 ] == Output[ 1 ][ 247 ]
# vi[ 1 ] == Output[ 1 ][ 248 ]
# vi[ 1 ] == Output[ 1 ][ 249 ]
# vi[ 1 ] == Output[ 1 ][ 250 ]
# vi[ 1 ] == Output[ 1 ][ 251 ]
# vi[ 1 ] == Output[ 1 ][ 252 ]
# vi[ 1 ] == Output[ 1 ][ 253 ]
# vi[ 1 ] == Output[ 1 ][ 254 ]
# vi[ 1 ] == Output[ 1 ][ 255 ]
# vi[ 1 ] == Output[ 1 ][ 256 ]
# vi[ 1 ] == Output[ 1 ][ 257 ]
# vi[ 1 ] == Output[ 1 ][ 258 ]
# vi[ 1 ] == Output[ 1 ][ 259 ]
# vi[ 1 ] == Output[ 1 ][ 260 ]
# vi[ 1 ] == Output[ 1 ][ 261 ]
# vi[ 1 ] == Output[ 1 ][ 262 ]
# vi[ 1 ] == Output[ 1 ][ 263 ]
# vi[ 1 ] == Output[ 1 ][ 264 ]
# vi[ 1 ] == Output[ 1 ][ 265 ]
# vi[ 1 ] == Output[ 1 ][ 266 ]
# vi[ 1 ] == Output[ 1 ][ 267 ]
# vi[ 1 ] == Output[ 1 ][ 268 ]
# vi[ 1 ] == Output[ 1 ][ 269 ]
# vi[ 1 ] == Output[ 1 ][ 270 ]
# vi[ 1 ] == Output[ 1 ][ 271 ]
# vi[ 1 ] == Output[ 1 ][ 272 ]
# vi[ 1 ] == Output[ 1 ][ 273 ]
# vi[ 1 ] == Output[ 1 ][ 274 ]
# vi[ 1 ] == Output[ 1 ][ 275 ]
# vi[ 1 ] == Output[ 1 ][ 276 ]
# vi[ 1 ] == Output[ 1 ][ 277 ]
# vi[ 1 ] == Output[ 1 ][ 278 ]
# vi[ 1 ] == Output[ 1 ][ 279 ]
# vi[ 1 ] == Output[ 1 ][ 280 ]
# vi[ 1 ] == Output[ 1 ][ 281 ]
# vi[ 1 ] == Output[ 1 ][ 282 ]
# vi[ 1 ] == Output[ 1 ][ 283 ]
# vi[ 1 ] == Output[ 1 ][ 284 ]
# vi[ 1 ] == Output[ 1 ][ 285 ]
# vi[ 1 ] == Output[ 1 ][ 286 ]
# vi[ 1 ] == Output[ 1 ][ 287 ]
# vi[ 1 ] == Output[ 1 ][ 288 ]
# vi[ 1 ] == Output[ 1 ][ 289 ]
# vi[ 1 ] == Output[ 1 ][ 290 ]
# vi[ 1 ] == Output[ 1 ][ 291 ]
# vi[ 1 ] == Output[ 1 ][ 292 ]
# vi[ 1 ] == Output[ 1 ][ 293 ]
# vi[ 1 ] == Output[ 1 ][ 294 ]
# vi[ 1 ] == Output[ 1 ][ 295 ]
# vi[ 1 ] == Output[ 1 ][ 296 ]
# vi[ 1 ] == Output[ 1 ][ 297 ]
# vi[ 1 ] == Output[ 1 ][ 298 ]
# vi[ 1 ] == Output[ 1 ][ 299 ]
# vi[ 1 ] == Output[ 1 ][ 300 ]
# vi[ 1 ] == Output[ 1 ][ 301 ]
# vi[ 1 ] == Output[ 1 ][ 302 ]
# vi[ 1 ] == Output[ 1 ][ 303 ]
# vi[ 1 ] == Output[ 1 ][ 304 ]
# vi[ 1 ] == Output[ 1 ][ 305 ]
# vi[ 1 ] == Output[ 1 ][ 306 ]
# vi[ 1 ] == Output[ 1 ][ 307 ]
# vi[ 1 ] == Output[ 1 ][ 308 ]
# vi[ 1 ] == Output[ 1 ][ 309 ]
# vi[ 1 ] == Output[ 1 ][ 310 ]
# vi[ 1 ] == Output[ 1 ][ 311 ]
# vi[ 1 ] == Output[ 1 ][ 312 ]
# vi[ 1 ] == Output[ 1 ][ 313 ]
# vi[ 1 ] == Output[ 1 ][ 314 ]
# vi[ 1 ] == Output[ 1 ][ 315 ]
# vi[ 1 ] == Output[ 1 ][ 316 ]
# vi[ 1 ] == Output[ 1 ][ 317 ]
# vi[ 1 ] == Output[ 1 ][ 318 ]
# vi[ 1 ] == Output[ 1 ][ 319 ]
# vi[ 1 ] == Output[ 1 ][ 320 ]
# vi[ 1 ] == Output[ 1 ][ 321 ]
# vi[ 1 ] == Output[ 1 ][ 322 ]
# vi[ 1 ] == Output[ 1 ][ 323 ]
# vi[ 1 ] == Output[ 1 ][ 324 ]
# vi[ 1 ] == Output[ 1 ][ 325 ]
# vi[ 1 ] == Output[ 1 ][ 326 ]
# vi[ 1 ] == Output[ 1 ][ 327 ]
# vi[ 1 ] == Output[ 1 ][ 328 ]
# vi[ 1 ] == Output[ 1 ][ 329 ]
# vi[ 1 ] == Output[ 1 ][ 330 ]
# vi[ 1 ] == Output[ 1 ][ 331 ]
# vi[ 1 ] == Output[ 1 ][ 332 ]
# vi[ 1 ] == Output[ 1 ][ 333 ]
# vi[ 1 ] == Output[ 1 ][ 334 ]
# vi[ 1 ] == Output[ 1 ][ 335 ]
# vi[ 1 ] == Output[ 1 ][ 336 ]
# vi[ 1 ] == Output[ 1 ][ 337 ]
# vi[ 1 ] == Output[ 1 ][ 338 ]
# vi[ 1 ] == Output[ 1 ][ 339 ]
# vi[ 1 ] == Output[ 1 ][ 340 ]
# vi[ 1 ] == Output[ 1 ][ 341 ]
# vi[ 1 ] == Output[ 1 ][ 342 ]
# vi[ 1 ] == Output[ 1 ][ 343 ]
# vi[ 1 ] == Output[ 1 ][ 344 ]
# vi[ 1 ] == Output[ 1 ][ 345 ]
# vi[ 1 ] == Output[ 1 ][ 346 ]
# vi[ 1 ] == Output[ 1 ][ 347 ]
# vi[ 1 ] == Output[ 1 ][ 348 ]
# vi[ 1 ] == Output[ 1 ][ 349 ]
# vi[ 1 ] == Output[ 1 ][ 350 ]
# vi[ 1 ] == Output[ 1 ][ 351 ]
# vi[ 1 ] == Output[ 1 ][ 352 ]
# vi[ 1 ] == Output[ 1 ][ 353 ]
# vi[ 1 ] == Output[ 1 ][ 354 ]
# vi[ 1 ] == Output[ 1 ][ 355 ]
# vi[ 1 ] == Output[ 1 ][ 356 ]
# vi[ 1 ] == Output[ 1 ][ 357 ]
# vi[ 1 ] == Output[ 1 ][ 358 ]
# vi[ 1 ] == Output[ 1 ][ 359 ]
# vi[ 1 ] == Output[ 1 ][ 360 ]
# vi[ 1 ] == Output[ 1 ][ 361 ]
# vi[ 1 ] == Output[ 1 ][ 362 ]
# vi[ 1 ] == Output[ 1 ][ 363 ]
# vi[ 1 ] == Output[ 1 ][ 364 ]
# vi[ 1 ] == Output[ 1 ][ 365 ]
# vi[ 1 ] == Output[ 1 ][ 366 ]
# vi[ 1 ] == Output[ 1 ][ 367 ]
# vi[ 1 ] == Output[ 1 ][ 368 ]
# vi[ 1 ] == Output[ 1 ][ 369 ]
# vi[ 1 ] == Output[ 1 ][ 370 ]
# vi[ 1 ] == Output[ 1 ][ 371 ]
# vi[ 1 ] == Output[ 1 ][ 372 ]
# vi[ 1 ] == Output[ 1 ][ 373 ]
# vi[ 1 ] == Output[ 1 ][ 374 ]
# vi[ 1 ] == Output[ 1 ][ 375 ]
# vi[ 1 ] == Output[ 1 ][ 376 ]
# vi[ 1 ] == Output[ 1 ][ 377 ]
# vi[ 1 ] == Output[ 1 ][ 378 ]
# vi[ 1 ] == Output[ 1 ][ 379 ]
# vi[ 1 ] == Output[ 1 ][ 380 ]
# Clustering 2 개수  571
# vi[ 2 ] == Output[ 2 ][ 0 ]
# vi[ 2 ] == Output[ 2 ][ 1 ]
# vi[ 2 ] == Output[ 2 ][ 2 ]
# vi[ 2 ] == Output[ 2 ][ 3 ]
# vi[ 2 ] == Output[ 2 ][ 4 ]
# vi[ 2 ] == Output[ 2 ][ 5 ]
# vi[ 2 ] == Output[ 2 ][ 6 ]
# vi[ 2 ] == Output[ 2 ][ 7 ]
# vi[ 2 ] == Output[ 2 ][ 8 ]
# vi[ 2 ] == Output[ 2 ][ 9 ]
# vi[ 2 ] == Output[ 2 ][ 10 ]
# vi[ 2 ] == Output[ 2 ][ 11 ]
# vi[ 2 ] == Output[ 2 ][ 12 ]
# vi[ 2 ] == Output[ 2 ][ 13 ]
# vi[ 2 ] == Output[ 2 ][ 14 ]
# vi[ 2 ] == Output[ 2 ][ 15 ]
# vi[ 2 ] == Output[ 2 ][ 16 ]
# vi[ 2 ] == Output[ 2 ][ 17 ]
# vi[ 2 ] == Output[ 2 ][ 18 ]
# vi[ 2 ] == Output[ 2 ][ 19 ]
# vi[ 2 ] == Output[ 2 ][ 20 ]
# vi[ 2 ] == Output[ 2 ][ 21 ]
# vi[ 2 ] == Output[ 2 ][ 22 ]
# vi[ 2 ] == Output[ 2 ][ 23 ]
# vi[ 2 ] == Output[ 2 ][ 24 ]
# vi[ 2 ] == Output[ 2 ][ 25 ]
# vi[ 2 ] == Output[ 2 ][ 26 ]
# vi[ 2 ] == Output[ 2 ][ 27 ]
# vi[ 2 ] == Output[ 2 ][ 28 ]
# vi[ 2 ] == Output[ 2 ][ 29 ]
# vi[ 2 ] == Output[ 2 ][ 30 ]
# vi[ 2 ] == Output[ 2 ][ 31 ]
# vi[ 2 ] == Output[ 2 ][ 32 ]
# vi[ 2 ] == Output[ 2 ][ 33 ]
# vi[ 2 ] == Output[ 2 ][ 34 ]
# vi[ 2 ] == Output[ 2 ][ 35 ]
# vi[ 2 ] == Output[ 2 ][ 36 ]
# vi[ 2 ] == Output[ 2 ][ 37 ]
# vi[ 2 ] == Output[ 2 ][ 38 ]
# vi[ 2 ] == Output[ 2 ][ 39 ]
# vi[ 2 ] == Output[ 2 ][ 40 ]
# vi[ 2 ] == Output[ 2 ][ 41 ]
# vi[ 2 ] == Output[ 2 ][ 42 ]
# vi[ 2 ] == Output[ 2 ][ 43 ]
# vi[ 2 ] == Output[ 2 ][ 44 ]
# vi[ 2 ] == Output[ 2 ][ 45 ]
# vi[ 2 ] == Output[ 2 ][ 46 ]
# vi[ 2 ] == Output[ 2 ][ 47 ]
# vi[ 2 ] == Output[ 2 ][ 48 ]
# vi[ 2 ] == Output[ 2 ][ 49 ]
# vi[ 2 ] == Output[ 2 ][ 50 ]
# vi[ 2 ] == Output[ 2 ][ 51 ]
# vi[ 2 ] == Output[ 2 ][ 52 ]
# vi[ 2 ] == Output[ 2 ][ 53 ]
# vi[ 2 ] == Output[ 2 ][ 54 ]
# vi[ 2 ] == Output[ 2 ][ 55 ]
# vi[ 2 ] == Output[ 2 ][ 56 ]
# vi[ 2 ] == Output[ 2 ][ 57 ]
# vi[ 2 ] == Output[ 2 ][ 58 ]
# vi[ 2 ] == Output[ 2 ][ 59 ]
# vi[ 2 ] == Output[ 2 ][ 60 ]
# vi[ 2 ] == Output[ 2 ][ 61 ]
# vi[ 2 ] == Output[ 2 ][ 62 ]
# vi[ 2 ] == Output[ 2 ][ 63 ]
# vi[ 2 ] == Output[ 2 ][ 64 ]
# vi[ 2 ] == Output[ 2 ][ 65 ]
# vi[ 2 ] == Output[ 2 ][ 66 ]
# vi[ 2 ] == Output[ 2 ][ 67 ]
# vi[ 2 ] == Output[ 2 ][ 68 ]
# vi[ 2 ] == Output[ 2 ][ 69 ]
# vi[ 2 ] == Output[ 2 ][ 70 ]
# vi[ 2 ] == Output[ 2 ][ 71 ]
# vi[ 2 ] == Output[ 2 ][ 72 ]
# vi[ 2 ] == Output[ 2 ][ 73 ]
# vi[ 2 ] == Output[ 2 ][ 74 ]
# vi[ 2 ] == Output[ 2 ][ 75 ]
# vi[ 2 ] == Output[ 2 ][ 76 ]
# vi[ 2 ] == Output[ 2 ][ 77 ]
# vi[ 2 ] == Output[ 2 ][ 78 ]
# vi[ 2 ] == Output[ 2 ][ 79 ]
# vi[ 2 ] == Output[ 2 ][ 80 ]
# vi[ 2 ] == Output[ 2 ][ 81 ]
# vi[ 2 ] == Output[ 2 ][ 82 ]
# vi[ 2 ] == Output[ 2 ][ 83 ]
# vi[ 2 ] == Output[ 2 ][ 84 ]
# vi[ 2 ] == Output[ 2 ][ 85 ]
# vi[ 2 ] == Output[ 2 ][ 86 ]
# vi[ 2 ] == Output[ 2 ][ 87 ]
# vi[ 2 ] == Output[ 2 ][ 88 ]
# vi[ 2 ] == Output[ 2 ][ 89 ]
# vi[ 2 ] == Output[ 2 ][ 90 ]
# vi[ 2 ] == Output[ 2 ][ 91 ]
# vi[ 2 ] == Output[ 2 ][ 92 ]
# vi[ 2 ] == Output[ 2 ][ 93 ]
# vi[ 2 ] == Output[ 2 ][ 94 ]
# vi[ 2 ] == Output[ 2 ][ 95 ]
# vi[ 2 ] == Output[ 2 ][ 96 ]
# vi[ 2 ] == Output[ 2 ][ 97 ]
# vi[ 2 ] == Output[ 2 ][ 98 ]
# vi[ 2 ] == Output[ 2 ][ 99 ]
# vi[ 2 ] == Output[ 2 ][ 100 ]
# vi[ 2 ] == Output[ 2 ][ 101 ]
# vi[ 2 ] == Output[ 2 ][ 102 ]
# vi[ 2 ] == Output[ 2 ][ 103 ]
# vi[ 2 ] == Output[ 2 ][ 104 ]
# vi[ 2 ] == Output[ 2 ][ 105 ]
# vi[ 2 ] == Output[ 2 ][ 106 ]
# vi[ 2 ] == Output[ 2 ][ 107 ]
# vi[ 2 ] == Output[ 2 ][ 108 ]
# vi[ 2 ] == Output[ 2 ][ 109 ]
# vi[ 2 ] == Output[ 2 ][ 110 ]
# vi[ 2 ] == Output[ 2 ][ 111 ]
# vi[ 2 ] == Output[ 2 ][ 112 ]
# vi[ 2 ] == Output[ 2 ][ 113 ]
# vi[ 2 ] == Output[ 2 ][ 114 ]
# vi[ 2 ] == Output[ 2 ][ 115 ]
# vi[ 2 ] == Output[ 2 ][ 116 ]
# vi[ 2 ] == Output[ 2 ][ 117 ]
# vi[ 2 ] == Output[ 2 ][ 118 ]
# vi[ 2 ] == Output[ 2 ][ 119 ]
# vi[ 2 ] == Output[ 2 ][ 120 ]
# vi[ 2 ] == Output[ 2 ][ 121 ]
# vi[ 2 ] == Output[ 2 ][ 122 ]
# vi[ 2 ] == Output[ 2 ][ 123 ]
# vi[ 2 ] == Output[ 2 ][ 124 ]
# vi[ 2 ] == Output[ 2 ][ 125 ]
# vi[ 2 ] == Output[ 2 ][ 126 ]
# vi[ 2 ] == Output[ 2 ][ 127 ]
# vi[ 2 ] == Output[ 2 ][ 128 ]
# vi[ 2 ] == Output[ 2 ][ 129 ]
# vi[ 2 ] == Output[ 2 ][ 130 ]
# vi[ 2 ] == Output[ 2 ][ 131 ]
# vi[ 2 ] == Output[ 2 ][ 132 ]
# vi[ 2 ] == Output[ 2 ][ 133 ]
# vi[ 2 ] == Output[ 2 ][ 134 ]
# vi[ 2 ] == Output[ 2 ][ 135 ]
# vi[ 2 ] == Output[ 2 ][ 136 ]
# vi[ 2 ] == Output[ 2 ][ 137 ]
# vi[ 2 ] == Output[ 2 ][ 138 ]
# vi[ 2 ] == Output[ 2 ][ 139 ]
# vi[ 2 ] == Output[ 2 ][ 140 ]
# vi[ 2 ] == Output[ 2 ][ 141 ]
# vi[ 2 ] == Output[ 2 ][ 142 ]
# vi[ 2 ] == Output[ 2 ][ 143 ]
# vi[ 2 ] == Output[ 2 ][ 144 ]
# vi[ 2 ] == Output[ 2 ][ 145 ]
# vi[ 2 ] == Output[ 2 ][ 146 ]
# vi[ 2 ] == Output[ 2 ][ 147 ]
# vi[ 2 ] == Output[ 2 ][ 148 ]
# vi[ 2 ] == Output[ 2 ][ 149 ]
# vi[ 2 ] == Output[ 2 ][ 150 ]
# vi[ 2 ] == Output[ 2 ][ 151 ]
# vi[ 2 ] == Output[ 2 ][ 152 ]
# vi[ 2 ] == Output[ 2 ][ 153 ]
# vi[ 2 ] == Output[ 2 ][ 154 ]
# vi[ 2 ] == Output[ 2 ][ 155 ]
# vi[ 2 ] == Output[ 2 ][ 156 ]
# vi[ 2 ] == Output[ 2 ][ 157 ]
# vi[ 2 ] == Output[ 2 ][ 158 ]
# vi[ 2 ] == Output[ 2 ][ 159 ]
# vi[ 2 ] == Output[ 2 ][ 160 ]
# vi[ 2 ] == Output[ 2 ][ 161 ]
# vi[ 2 ] == Output[ 2 ][ 162 ]
# vi[ 2 ] == Output[ 2 ][ 163 ]
# vi[ 2 ] == Output[ 2 ][ 164 ]
# vi[ 2 ] == Output[ 2 ][ 165 ]
# vi[ 2 ] == Output[ 2 ][ 166 ]
# vi[ 2 ] == Output[ 2 ][ 167 ]
# vi[ 2 ] == Output[ 2 ][ 168 ]
# vi[ 2 ] == Output[ 2 ][ 169 ]
# vi[ 2 ] == Output[ 2 ][ 170 ]
# vi[ 2 ] == Output[ 2 ][ 171 ]
# vi[ 2 ] == Output[ 2 ][ 172 ]
# vi[ 2 ] == Output[ 2 ][ 173 ]
# vi[ 2 ] == Output[ 2 ][ 174 ]
# vi[ 2 ] == Output[ 2 ][ 175 ]
# vi[ 2 ] == Output[ 2 ][ 176 ]
# vi[ 2 ] == Output[ 2 ][ 177 ]
# vi[ 2 ] == Output[ 2 ][ 178 ]
# vi[ 2 ] == Output[ 2 ][ 179 ]
# vi[ 2 ] == Output[ 2 ][ 180 ]
# vi[ 2 ] == Output[ 2 ][ 181 ]
# vi[ 2 ] == Output[ 2 ][ 182 ]
# vi[ 2 ] == Output[ 2 ][ 183 ]
# vi[ 2 ] == Output[ 2 ][ 184 ]
# vi[ 2 ] == Output[ 2 ][ 185 ]
# vi[ 2 ] == Output[ 2 ][ 186 ]
# vi[ 2 ] == Output[ 2 ][ 187 ]
# vi[ 2 ] == Output[ 2 ][ 188 ]
# vi[ 2 ] == Output[ 2 ][ 189 ]
# vi[ 2 ] == Output[ 2 ][ 190 ]
# vi[ 2 ] == Output[ 2 ][ 191 ]
# vi[ 2 ] == Output[ 2 ][ 192 ]
# vi[ 2 ] == Output[ 2 ][ 193 ]
# vi[ 2 ] == Output[ 2 ][ 194 ]
# vi[ 2 ] == Output[ 2 ][ 195 ]
# vi[ 2 ] == Output[ 2 ][ 196 ]
# vi[ 2 ] == Output[ 2 ][ 197 ]
# vi[ 2 ] == Output[ 2 ][ 198 ]
# vi[ 2 ] == Output[ 2 ][ 199 ]
# vi[ 2 ] == Output[ 2 ][ 200 ]
# vi[ 2 ] == Output[ 2 ][ 201 ]
# vi[ 2 ] == Output[ 2 ][ 202 ]
# vi[ 2 ] == Output[ 2 ][ 203 ]
# vi[ 2 ] == Output[ 2 ][ 204 ]
# vi[ 2 ] == Output[ 2 ][ 205 ]
# vi[ 2 ] == Output[ 2 ][ 206 ]
# vi[ 2 ] == Output[ 2 ][ 207 ]
# vi[ 2 ] == Output[ 2 ][ 208 ]
# vi[ 2 ] == Output[ 2 ][ 209 ]
# vi[ 2 ] == Output[ 2 ][ 210 ]
# vi[ 2 ] == Output[ 2 ][ 211 ]
# vi[ 2 ] == Output[ 2 ][ 212 ]
# vi[ 2 ] == Output[ 2 ][ 213 ]
# vi[ 2 ] == Output[ 2 ][ 214 ]
# vi[ 2 ] == Output[ 2 ][ 215 ]
# vi[ 2 ] == Output[ 2 ][ 216 ]
# vi[ 2 ] == Output[ 2 ][ 217 ]
# vi[ 2 ] == Output[ 2 ][ 218 ]
# vi[ 2 ] == Output[ 2 ][ 219 ]
# vi[ 2 ] == Output[ 2 ][ 220 ]
# vi[ 2 ] == Output[ 2 ][ 221 ]
# vi[ 2 ] == Output[ 2 ][ 222 ]
# vi[ 2 ] == Output[ 2 ][ 223 ]
# vi[ 2 ] == Output[ 2 ][ 224 ]
# vi[ 2 ] == Output[ 2 ][ 225 ]
# vi[ 2 ] == Output[ 2 ][ 226 ]
# vi[ 2 ] == Output[ 2 ][ 227 ]
# vi[ 2 ] == Output[ 2 ][ 228 ]
# vi[ 2 ] == Output[ 2 ][ 229 ]
# vi[ 2 ] == Output[ 2 ][ 230 ]
# vi[ 2 ] == Output[ 2 ][ 231 ]
# vi[ 2 ] == Output[ 2 ][ 232 ]
# vi[ 2 ] == Output[ 2 ][ 233 ]
# vi[ 2 ] == Output[ 2 ][ 234 ]
# vi[ 2 ] == Output[ 2 ][ 235 ]
# vi[ 2 ] == Output[ 2 ][ 236 ]
# vi[ 2 ] == Output[ 2 ][ 237 ]
# vi[ 2 ] == Output[ 2 ][ 238 ]
# vi[ 2 ] == Output[ 2 ][ 239 ]
# vi[ 2 ] == Output[ 2 ][ 240 ]
# vi[ 2 ] == Output[ 2 ][ 241 ]
# vi[ 2 ] == Output[ 2 ][ 242 ]
# vi[ 2 ] == Output[ 2 ][ 243 ]
# vi[ 2 ] == Output[ 2 ][ 244 ]
# vi[ 2 ] == Output[ 2 ][ 245 ]
# vi[ 2 ] == Output[ 2 ][ 246 ]
# vi[ 2 ] == Output[ 2 ][ 247 ]
# vi[ 2 ] == Output[ 2 ][ 248 ]
# vi[ 2 ] == Output[ 2 ][ 249 ]
# vi[ 2 ] == Output[ 2 ][ 250 ]
# vi[ 2 ] == Output[ 2 ][ 251 ]
# vi[ 2 ] == Output[ 2 ][ 252 ]
# vi[ 2 ] == Output[ 2 ][ 253 ]
# vi[ 2 ] == Output[ 2 ][ 254 ]
# vi[ 2 ] == Output[ 2 ][ 255 ]
# vi[ 2 ] == Output[ 2 ][ 256 ]
# vi[ 2 ] == Output[ 2 ][ 257 ]
# vi[ 2 ] == Output[ 2 ][ 258 ]
# vi[ 2 ] == Output[ 2 ][ 259 ]
# vi[ 2 ] == Output[ 2 ][ 260 ]
# vi[ 2 ] == Output[ 2 ][ 261 ]
# vi[ 2 ] == Output[ 2 ][ 262 ]
# vi[ 2 ] == Output[ 2 ][ 263 ]
# vi[ 2 ] == Output[ 2 ][ 264 ]
# vi[ 2 ] == Output[ 2 ][ 265 ]
# vi[ 2 ] == Output[ 2 ][ 266 ]
# vi[ 2 ] == Output[ 2 ][ 267 ]
# vi[ 2 ] == Output[ 2 ][ 268 ]
# vi[ 2 ] == Output[ 2 ][ 269 ]
# vi[ 2 ] == Output[ 2 ][ 270 ]
# vi[ 2 ] == Output[ 2 ][ 271 ]
# vi[ 2 ] == Output[ 2 ][ 272 ]
# vi[ 2 ] == Output[ 2 ][ 273 ]
# vi[ 2 ] == Output[ 2 ][ 274 ]
# vi[ 2 ] == Output[ 2 ][ 275 ]
# vi[ 2 ] == Output[ 2 ][ 276 ]
# vi[ 2 ] == Output[ 2 ][ 277 ]
# vi[ 2 ] == Output[ 2 ][ 278 ]
# vi[ 2 ] == Output[ 2 ][ 279 ]
# vi[ 2 ] == Output[ 2 ][ 280 ]
# vi[ 2 ] == Output[ 2 ][ 281 ]
# vi[ 2 ] == Output[ 2 ][ 282 ]
# vi[ 2 ] == Output[ 2 ][ 283 ]
# vi[ 2 ] == Output[ 2 ][ 284 ]
# vi[ 2 ] == Output[ 2 ][ 285 ]
# vi[ 2 ] == Output[ 2 ][ 286 ]
# vi[ 2 ] == Output[ 2 ][ 287 ]
# vi[ 2 ] == Output[ 2 ][ 288 ]
# vi[ 2 ] == Output[ 2 ][ 289 ]
# vi[ 2 ] == Output[ 2 ][ 290 ]
# vi[ 2 ] == Output[ 2 ][ 291 ]
# vi[ 2 ] == Output[ 2 ][ 292 ]
# vi[ 2 ] == Output[ 2 ][ 293 ]
# vi[ 2 ] == Output[ 2 ][ 294 ]
# vi[ 2 ] == Output[ 2 ][ 295 ]
# vi[ 2 ] == Output[ 2 ][ 296 ]
# vi[ 2 ] == Output[ 2 ][ 297 ]
# vi[ 2 ] == Output[ 2 ][ 298 ]
# vi[ 2 ] == Output[ 2 ][ 299 ]
# vi[ 2 ] == Output[ 2 ][ 300 ]
# vi[ 2 ] == Output[ 2 ][ 301 ]
# vi[ 2 ] == Output[ 2 ][ 302 ]
# vi[ 2 ] == Output[ 2 ][ 303 ]
# vi[ 2 ] == Output[ 2 ][ 304 ]
# vi[ 2 ] == Output[ 2 ][ 305 ]
# vi[ 2 ] == Output[ 2 ][ 306 ]
# vi[ 2 ] == Output[ 2 ][ 307 ]
# vi[ 2 ] == Output[ 2 ][ 308 ]
# vi[ 2 ] == Output[ 2 ][ 309 ]
# vi[ 2 ] == Output[ 2 ][ 310 ]
# vi[ 2 ] == Output[ 2 ][ 311 ]
# vi[ 2 ] == Output[ 2 ][ 312 ]
# vi[ 2 ] == Output[ 2 ][ 313 ]
# vi[ 2 ] == Output[ 2 ][ 314 ]
# vi[ 2 ] == Output[ 2 ][ 315 ]
# vi[ 2 ] == Output[ 2 ][ 316 ]
# vi[ 2 ] == Output[ 2 ][ 317 ]
# vi[ 2 ] == Output[ 2 ][ 318 ]
# vi[ 2 ] == Output[ 2 ][ 319 ]
# vi[ 2 ] == Output[ 2 ][ 320 ]
# vi[ 2 ] == Output[ 2 ][ 321 ]
# vi[ 2 ] == Output[ 2 ][ 322 ]
# vi[ 2 ] == Output[ 2 ][ 323 ]
# vi[ 2 ] == Output[ 2 ][ 324 ]
# vi[ 2 ] == Output[ 2 ][ 325 ]
# vi[ 2 ] == Output[ 2 ][ 326 ]
# vi[ 2 ] == Output[ 2 ][ 327 ]
# vi[ 2 ] == Output[ 2 ][ 328 ]
# vi[ 2 ] == Output[ 2 ][ 329 ]
# vi[ 2 ] == Output[ 2 ][ 330 ]
# vi[ 2 ] == Output[ 2 ][ 331 ]
# vi[ 2 ] == Output[ 2 ][ 332 ]
# vi[ 2 ] == Output[ 2 ][ 333 ]
# vi[ 2 ] == Output[ 2 ][ 334 ]
# vi[ 2 ] == Output[ 2 ][ 335 ]
# vi[ 2 ] == Output[ 2 ][ 336 ]
# vi[ 2 ] == Output[ 2 ][ 337 ]
# vi[ 2 ] == Output[ 2 ][ 338 ]
# vi[ 2 ] == Output[ 2 ][ 339 ]
# vi[ 2 ] == Output[ 2 ][ 340 ]
# vi[ 2 ] == Output[ 2 ][ 341 ]
# vi[ 2 ] == Output[ 2 ][ 342 ]
# vi[ 2 ] == Output[ 2 ][ 343 ]
# vi[ 2 ] == Output[ 2 ][ 344 ]
# vi[ 2 ] == Output[ 2 ][ 345 ]
# vi[ 2 ] == Output[ 2 ][ 346 ]
# vi[ 2 ] == Output[ 2 ][ 347 ]
# vi[ 2 ] == Output[ 2 ][ 348 ]
# vi[ 2 ] == Output[ 2 ][ 349 ]
# vi[ 2 ] == Output[ 2 ][ 350 ]
# vi[ 2 ] == Output[ 2 ][ 351 ]
# vi[ 2 ] == Output[ 2 ][ 352 ]
# vi[ 2 ] == Output[ 2 ][ 353 ]
# vi[ 2 ] == Output[ 2 ][ 354 ]
# vi[ 2 ] == Output[ 2 ][ 355 ]
# vi[ 2 ] == Output[ 2 ][ 356 ]
# vi[ 2 ] == Output[ 2 ][ 357 ]
# vi[ 2 ] == Output[ 2 ][ 358 ]
# vi[ 2 ] == Output[ 2 ][ 359 ]
# vi[ 2 ] == Output[ 2 ][ 360 ]
# vi[ 2 ] == Output[ 2 ][ 361 ]
# vi[ 2 ] == Output[ 2 ][ 362 ]
# vi[ 2 ] == Output[ 2 ][ 363 ]
# vi[ 2 ] == Output[ 2 ][ 364 ]
# vi[ 2 ] == Output[ 2 ][ 365 ]
# vi[ 2 ] == Output[ 2 ][ 366 ]
# vi[ 2 ] == Output[ 2 ][ 367 ]
# vi[ 2 ] == Output[ 2 ][ 368 ]
# vi[ 2 ] == Output[ 2 ][ 369 ]
# vi[ 2 ] == Output[ 2 ][ 370 ]
# vi[ 2 ] == Output[ 2 ][ 371 ]
# vi[ 2 ] == Output[ 2 ][ 372 ]
# vi[ 2 ] == Output[ 2 ][ 373 ]
# vi[ 2 ] == Output[ 2 ][ 374 ]
# vi[ 2 ] == Output[ 2 ][ 375 ]
# vi[ 2 ] == Output[ 2 ][ 376 ]
# vi[ 2 ] == Output[ 2 ][ 377 ]
# vi[ 2 ] == Output[ 2 ][ 378 ]
# vi[ 2 ] == Output[ 2 ][ 379 ]
# vi[ 2 ] == Output[ 2 ][ 380 ]
# vi[ 2 ] == Output[ 2 ][ 381 ]
# vi[ 2 ] == Output[ 2 ][ 382 ]
# vi[ 2 ] == Output[ 2 ][ 383 ]
# vi[ 2 ] == Output[ 2 ][ 384 ]
# vi[ 2 ] == Output[ 2 ][ 385 ]
# vi[ 2 ] == Output[ 2 ][ 386 ]
# vi[ 2 ] == Output[ 2 ][ 387 ]
# vi[ 2 ] == Output[ 2 ][ 388 ]
# vi[ 2 ] == Output[ 2 ][ 389 ]
# vi[ 2 ] == Output[ 2 ][ 390 ]
# vi[ 2 ] == Output[ 2 ][ 391 ]
# vi[ 2 ] == Output[ 2 ][ 392 ]
# vi[ 2 ] == Output[ 2 ][ 393 ]
# vi[ 2 ] == Output[ 2 ][ 394 ]
# vi[ 2 ] == Output[ 2 ][ 395 ]
# vi[ 2 ] == Output[ 2 ][ 396 ]
# vi[ 2 ] == Output[ 2 ][ 397 ]
# vi[ 2 ] == Output[ 2 ][ 398 ]
# vi[ 2 ] == Output[ 2 ][ 399 ]
# vi[ 2 ] == Output[ 2 ][ 400 ]
# vi[ 2 ] == Output[ 2 ][ 401 ]
# vi[ 2 ] == Output[ 2 ][ 402 ]
# vi[ 2 ] == Output[ 2 ][ 403 ]
# vi[ 2 ] == Output[ 2 ][ 404 ]
# vi[ 2 ] == Output[ 2 ][ 405 ]
# vi[ 2 ] == Output[ 2 ][ 406 ]
# vi[ 2 ] == Output[ 2 ][ 407 ]
# vi[ 2 ] == Output[ 2 ][ 408 ]
# vi[ 2 ] == Output[ 2 ][ 409 ]
# vi[ 2 ] == Output[ 2 ][ 410 ]
# vi[ 2 ] == Output[ 2 ][ 411 ]
# vi[ 2 ] == Output[ 2 ][ 412 ]
# vi[ 2 ] == Output[ 2 ][ 413 ]
# vi[ 2 ] == Output[ 2 ][ 414 ]
# vi[ 2 ] == Output[ 2 ][ 415 ]
# vi[ 2 ] == Output[ 2 ][ 416 ]
# vi[ 2 ] == Output[ 2 ][ 417 ]
# vi[ 2 ] == Output[ 2 ][ 418 ]
# vi[ 2 ] == Output[ 2 ][ 419 ]
# vi[ 2 ] == Output[ 2 ][ 420 ]
# vi[ 2 ] == Output[ 2 ][ 421 ]
# vi[ 2 ] == Output[ 2 ][ 422 ]
# vi[ 2 ] == Output[ 2 ][ 423 ]
# vi[ 2 ] == Output[ 2 ][ 424 ]
# vi[ 2 ] == Output[ 2 ][ 425 ]
# vi[ 2 ] == Output[ 2 ][ 426 ]
# vi[ 2 ] == Output[ 2 ][ 427 ]
# vi[ 2 ] == Output[ 2 ][ 428 ]
# vi[ 2 ] == Output[ 2 ][ 429 ]
# vi[ 2 ] == Output[ 2 ][ 430 ]
# vi[ 2 ] == Output[ 2 ][ 431 ]
# vi[ 2 ] == Output[ 2 ][ 432 ]
# vi[ 2 ] == Output[ 2 ][ 433 ]
# vi[ 2 ] == Output[ 2 ][ 434 ]
# vi[ 2 ] == Output[ 2 ][ 435 ]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-a97fd9ca4de3> in <module>
#       8         for a in range(m):
#       9
# ---> 10             if np.array_equal(vi[a],Output[k][i]) == True:
#      11
#      12                 print("vi[",k,"] == Output[",k ,"][", i,"]")
#
# <__array_function__ internals> in array_equal(*args, **kwargs)
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/numpy/core/numeric.py in array_equal(a1, a2)
#    2325     if a1.shape != a2.shape:
#    2326         return False
# -> 2327     return bool(asarray(a1 == a2).all())
#    2328
#    2329
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      46
#      47 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 48     return umr_all(a, axis, dtype, out, keepdims)
#      49
#      50 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:

# %%
color=['red','blue','green','purple','yellow']
labels=['virusA','virusB','virusC','virusD','virusE']
for k in range(K):
    plt.scatter(Output[k+1][:,0],Output[k+1][:,1],c=color[k],label=labels[k])
#plt.scatter(Centroids[0,:],Centroids[1,:],s=100,c='yellow',label='Centroids')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-5b7c1b083efe> in <module>
#       2 labels=['virusA','virusB','virusC','virusD','virusE']
#       3 for k in range(K):
# ----> 4     plt.scatter(Output[k+1][:,0],Output[k+1][:,1],c=color[k],label=labels[k])
#       5 #plt.scatter(Centroids[0,:],Centroids[1,:],s=100,c='yellow',label='Centroids')
#       6
#
# IndexError: list index out of range

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
silhouette_score(vi,np.argmin(EuclidianDistance,axis=1))
# Out:
# 0.19139820104875452

# %%
from Bio import SeqIO

records = list(SeqIO.parse("tt.fa", "fasta"))
print(records[0].description)  # first record
print(records[-1].id)  # last record
# Out:
# scaffold-0
# scaffold-7706

# %%
from sklearn.cluster import DBSCAN
model = DBSCAN(eps=0.0175,min_samples=5)
clusters = model.fit_predict(vi)

df = pd.DataFrame(clusters,columns=["cluster"]).reset_index()

df.colums = ["cluster"]

print(df.head)
print(df.groupby(["cluster"]).count())

for k in range(100):
    if df["cluster"][k] == 0:
        plt.scatter(vi[k][0],vi[k][1],color='green')
    if df["cluster"][k] == 1:
        plt.scatter(vi[k][0],vi[k][1],color='blue')
    if df["cluster"][k] == 2:
        plt.scatter(vi[k][0],vi[k][1],color='black')
    if df["cluster"][k] == 3:
        plt.scatter(vi[k][0],vi[k][1],color='orange')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-41795da88bbd> in <module>
#       1 from sklearn.cluster import DBSCAN
#       2 model = DBSCAN(eps=0.0175,min_samples=5)
# ----> 3 clusters = model.fit_predict(vi)
#       4
#       5 df = pd.DataFrame(clusters,columns=["cluster"]).reset_index()
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/sklearn/cluster/_dbscan.py in fit_predict(self, X, y, sample_weight)
#     389             Cluster labels. Noisy samples are given the label -1.
#     390         """
# --> 391         self.fit(X, sample_weight=sample_weight)
#     392         return self.labels_
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/sklearn/cluster/_dbscan.py in fit(self, X, y, sample_weight)
#     335         # This has worst case O(n^2) memory complexity
#     336         neighborhoods = neighbors_model.radius_neighbors(X,
# --> 337                                                          return_distance=False)
#     338
#     339         if sample_weight is None:
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/sklearn/neighbors/_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#     970                               sort_results=sort_results)
#     971
# --> 972                 for s in gen_even_slices(X.shape[0], n_jobs)
#     973             )
#     974             if return_distance:
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/sklearn/neighbors/_base.py in _tree_query_radius_parallel_helper(tree, *args, **kwargs)
#     788     cloudpickle under PyPy.
#     789     """
# --> 790     return tree.query_radius(*args, **kwargs)
#     791
#     792
#
# KeyboardInterrupt:

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
data = np.append(Output[1],Output[2],axis=0)
data2 = np.append(data,Output[3],axis=0)
data3 = np.append(data2,Output[4],axis=0)
data4 = np.append(data3,Output[5],axis=0)
data5 = np.append(data4,Output[6],axis=0)
data6 = np.append(data5,Output[7],axis=0)
data7 = np.append(data6,Output[8],axis=0)
data8 = np.append(data7,Output[9],axis=0)
data9 = np.append(data8,Output[10],axis=0)
data10 = np.append(data9,Output[11],axis=0)
data11 = np.append(data10,Output[12],axis=0)
data12 = np.append(data11,Output[13],axis=0)
data13 = np.append(data12,Output[14],axis=0)
data14 = np.append(data13,Output[15],axis=0)
data15 = np.append(data14,Output[16],axis=0)
data16 = np.append(data15,Output[17],axis=0)
data17 = np.append(data16,Output[18],axis=0)
data18 = np.append(data17,Output[19],axis=0)
data19 = np.append(data18,Output[20],axis=0)


labels  = ["cluster1" for x in range(len(Output[1]))]
labels  += ["cluster2" for x in range(len(Output[2]))]
labels  += ["cluster3" for x in range(len(Output[3]))]
labels  += ["cluster4" for x in range(len(Output[4]))]
labels  += ["cluster5" for x in range(len(Output[5]))]
labels  += ["cluster6" for x in range(len(Output[6]))]
labels  += ["cluster7" for x in range(len(Output[7]))]
labels  += ["cluster8" for x in range(len(Output[8]))]
labels  += ["cluster9" for x in range(len(Output[9]))]
labels  += ["cluster10" for x in range(len(Output[10]))]
labels  += ["cluster11" for x in range(len(Output[11]))]
labels  += ["cluster12" for x in range(len(Output[12]))]
labels  += ["cluster13" for x in range(len(Output[13]))]
labels  += ["cluster14" for x in range(len(Output[14]))]
labels  += ["cluster15" for x in range(len(Output[15]))]
labels  += ["cluster16" for x in range(len(Output[16]))]
labels  += ["cluster17" for x in range(len(Output[17]))]
labels  += ["cluster18" for x in range(len(Output[18]))]
labels  += ["cluster19" for x in range(len(Output[19]))]
labels  += ["cluster20" for x in range(len(Output[20]))]

labels = np.array(labels)


tsne = TSNE(learning_rate=10)
data_2d = tsne.fit_transform(data19)
print(data_2d.shape)
fig = plt.figure(figsize=(20, 20))
sns.scatterplot(data_2d[:,0], data_2d[:,1], hue=labels)

pca = PCA()
data_2d = pca.fit_transform(data19)
fig = plt.figure(figsize=(20, 20))
sns.scatterplot(data_2d[:,0], data_2d[:,1], hue=labels)
# Out:
# (5952, 2)
# /Users/suhyeonglee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Users/suhyeonglee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:>
